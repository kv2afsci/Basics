# %% [markdown]
# <a href="https://colab.research.google.com/github/kv2afsci/Python-Basics/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# PRACTICAL NO: 1
#
#
# OBJECTIVE
# Write a program to input a "Welcome" Message and display it.
#
#
# SOURCE CODE:

# %%
name= input("Please enter your name:")
print("Welcome", name )
# Out:
# Please enter your name:Shrinivas
# Welcome Shrinivas

# %% [markdown]
# PRACTICAL NO: 2
#
#
# OBJECTIVE
# Write a program that accepts radius of a circle and prints its area.
#
#
# SOURCE CODE:

# %%
r=int(input('Enter the radius of circle:'))
Area=3.14*r**2
print('The area of the circle is:', Area)
# Out:
# Enter the radius of circle:4
# The area of the circle is: 50.24

# %% [markdown]
# PRACTICAL NO: 3
#
#
# OBJECTIVE
# Write a program that inputs a students marks in three subjects (out of
# 100) and prints the percentage marks.
#
#
# SOURCE CODE:

# %%
print('Enter the marks of five subjects out of 100 each')
subl =float(input('Enter the marks of first subject:'))
sub2=float(input('Enter the marks of second subject:'))
sub3=float(input('Enter the marks of third subject'))
sub4=float(input('Enter the marks of second subject:'))
sub5=float(input('9Enter the marks of third subject:'))

average=(subl +sub2+sub3+sub4+sub5)/5
print('The Average marks are:', average)

# %% [markdown]
# PRACTICAL NO: 4
#
#
# OBJECTIVE
# Write a program that reads the number n and print the value of n2, n3
# and n4.
#
#
#
# SOURCE CODE:

# %%
n=float(input('Enter the value of n:'))
a=n**2
b=n**3
c=n**4
print('The value of n2 is:', a)
print('The value of n3 is:', b)
print('The value of n4 is:', c)

# %% [markdown]
# PRACTICAL NO: 5
#
#
# OBJECTIVE
# Write a program to calculate simple interest.
#
#
# SOURCE CODE:

# %%
P=float(input('Enter the principal amount in Rs.:'))
R=float(input('Enter the rate of interest:'))
T=float(input('Enter the time in years:'))
SI=(P*R*T)/100
print('The simple interest is: Rs.', SI,)

# %% [markdown]
# PRACTICAL NO: 6
#
#
# OBJECTIVE
# Write a program to input length and breadth of rectangle and calculate
# its area.
#
#
# SOURCE CODE:

# %%
l=float(input('Enter the length of rectangle:'))
b=float(input('Enter the breadth of rectangle:'))
area=l*b
print('Rectangle Specifications')
print('Lenght=', l)
print('Breadth=', b)
print('Area=', area)

# %% [markdown]
# PRACTICAL NO: 7
#
#
# OBJECTIVE
# Write a program to obtain temperature in Celsius and convert it into
# Fahrenheit.
# Formula : F = C*(9/5)+ 32
#
#
#
# SOURCE CODE:

# %%
cel = float(input("Enter the temperature:"))
Fah = (9/5)*cel+ 32
print ("The temperature in Fahrenheit is ", Fah)

# %% [markdown]
# PRACTICAL NO: 8
#
#
# OBJECTIVE
# Write a program to read details like name, class, age of a student and
# then print the details in same line and then in separate lines.
#
#
#
# SOURCE CODE:

# %%
n = input("Enter name of Student:")
c = int(input("Enter class of student:"))
a = int(input("Enter age of student: "))
print("Name:", n, "Class:", c, "Age:", a)
print()
print()
print("Name:", n)
print("Class:", c)
print("Age:", a)

# %% [markdown]
# PRACTICAL NO: 9
#
#
# OBJECTIVE
# Write a program to enter a number and check if it is a prime number or a composite number.
#
#
# SOURCE CODE:

# %%
num=int(input('Enter the number:'))
for i in range(2,num//2+1):
  if num%i==0:
    print('It is Composite Number.')
    break
  else:
    print('lt is a Prime Number:')
    break

# %% [markdown]
# PRACTICAL NO: 10
#
#
# OBJECTIVE
# Write a Program to display the n terms of Fibonacci series.
#
#
# SOURCE CODE:

# %%
n = int(input("Enter the Range Number: "))
a = 0
b = 1
if n == 1:
print(a)
else:
print(a, b, end=' ')
for i in range(2,n):
c = a + b
a = b
b = c
print(c,end=' ')

# %% [markdown]
# PRACTICAL NO: 11
#
#
# OBJECTIVE
# Write a program to input two numbers and display the largest/smaller
# number.
#
# SOURCE CODE:

# %%
a=int(input('Enter the first integer:'))
b=int(input('Enter the second integer:'))
if a!=b:
  if a>b:
    max=a
    min=b
  if b>a:
    max=b
    min=a
    print(max, 'is the largest integer.')
    print(min, 'is the smaller integer.')
else:
  print('Both are equal.')

# %% [markdown]
# PRACTICAL NO: 12
#
#
# OBJECTIVE
# Write a program to input three integers and display the largest/smallest
# number.
#
#
#
# SOURCE CODE:

# %%
num1 = int(input('Enter First number :'))
num2 = int(input('Enter Second number: '))
num3 = int(input('Enter Third number: '))

#largest number
if (num1 >= num2) and (num1 >= num3):
  largest_num = num1
if (num2 >= num1) and (num2 >= num3):
  largest_num = num2
if (num3 >= num1) and (num3 >= num2):
  largest_num = num3

print("The largest number is :", largest_num)

#smallest num = num1
if (num1 <= num2) and (num1 <= num3):
  smallest_num = num1
if (num2 <= num1) and (num2 <= num3):
  smallest_num = num2
if (num3 <= num1) and (num3 <= num2):
  smallest_num = num3

print("The smallest number is :", smallest_num)

# %% [markdown]
# PRACTICAL NO: 13
#
#
# OBJECTIVE
# Write a program to take a list of items and print each item in the list
# using for loop.
#
#
#
# SOURCE CODE:

# %%
Animals=['cat','dog', 'mouse', 'hamster']
print("Animals in given list are : ")
for a in Animals:
  print(a)

# %% [markdown]
# PRACTICAL NO: 14
#
# OBJECTIVE
# Write a program to create a list namely test having at least 3 integers, 2
# floating point and two strings.
# test=[11,33,99, 20.25, 95.2,'Apple', 'Pencil']
#
# SOURCE CODE:

# %%
test=[11,33,99, 20.25, 95.2,'Apple', 'Pencil']
print('The Given List Test=', test)
#1. print the first element of the list test
print('The first element of the list test is: ', test[0])
#2. print the last element of the list test
print('The last element of the list test is: ', test[-1])
#3. print the 2nd element of the list test
print('The 2nd element of the list test is: ', test[1])
#4. print the 4th element of the list test
print('The 4th element of the list test is: ', test[3])
#5. print the 2nd last element of the list test
print('The 2nd last element of the list test is: ', test[-2])
#6. print all element of the list test
print('All element of the list test are: ', test)
#7. print the size of the list test
print('The size of the list test is: ', len(test))

# %% [markdown]
# PRACTICAL NO: 15
#
#
# OBJECTIVE
# Write a program to create a 2D array using NumPy.
#
#
# SOURCE CODE:

# %%
#import numpy package
import numpy as np
#Creating array using arange() function
arr=np.arange(5,45,5)
#reshaping array for 2D
arr=arr.reshape(2,4)
#printing array
print(arr)

# %% [markdown]
# PRACTICAL NO: 16
#
#
# OBJECTIVE
# Write a program to represent the data on the ratings of mobile games on bar chart. The sample data is given as: Pubg, FreeFire, MineCraft, GTA-V. Call of duty, FIFA 22.
#
# The rating for each game is as: 4.5,4.8,4.7,4.6,4.1 ,4.3.
#
# SOURCE CODE:

# %%
#lmport package for Matplot Library
import matplotlib.pyplot as plt
#Creating lists for data
games=['Pubg', 'FreeFire', 'MineCraft', 'GTA-V','Call of duty', 'FIFA 22']
rating=[4.5,4.8,4.7,4.6,4.1,4.3]
#Creating bar graph with different bar colours
plt.bar(games,rating,color=['black','red', 'green', 'blue', 'yellow'])
#Custornizing the graph
plt.title("Games Rating 2022")
plt.xlabel('Games')
plt.ylabel('Rating')
plt.legend();plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# PRACTICAL NO: 17
#
#
# OBJECTIVE
# Load Image and give the title of image
#
#
# SOURCE CODE:

# %%
#import required module cv2. matplotlib and numpy
import cv2
import matplotlib.pyplot as ptt
import numpy as np
#Load the image file into memory
img = cv2.imread('octopus.png')
#Display Image
plt.imshow(img)
plt.title('Octopus')
plt.axis('off')
plt.show()
